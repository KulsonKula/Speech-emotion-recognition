# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import LearningRateScheduler
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from tensorflow.keras import layers
from tensorflow.keras import models
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# WARNING:tensorflow:From c:\Users\Kuba\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
model=tf.keras.models.load_model("model.h5")
Features=pd.read_csv("../data/data_proccesed.csv")
X = Features.iloc[: ,:-1].values
Y = Features['labels'].values
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming `model` and `x_test`, `y_test` are already defined and loaded

# List of labels
commands = ["neutral", "calm", "happy", "sad", "angry", "fearful", "disgust", "surprised"]

# Predict the classes
y_pred = np.argmax(model.predict(x_test), axis=1)
y_true = y_test

# Calculate accuracy
test_acc = sum(y_pred == y_true) / len(y_true)
print(f'Test set accuracy: {test_acc:.0%}')

# Compute confusion matrix
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred).numpy()

# Plot the filtered confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(filtered_confusion_mtx, 
            xticklabels=filtered_commands, 
            yticklabels=filtered_commands, 
            annot=True, 
            fmt='g', 
            cmap='coolwarm',
            cbar_kws={'label': 'Scale'})

plt.xlabel('Prediction')
plt.ylabel('Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 27/27 [==============================] - 3s 101ms/step
# Test set accuracy: 79%
